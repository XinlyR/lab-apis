# %% [markdown]
# # Lab | APIs

# %% [markdown]
# In order to use the `Spotify` API (`SpotiPy`), create an account in `Spotify` and follow [these](https://developer.spotify.com/documentation/general/guides/app-settings/) steps.

# %% [markdown]
# ## Authentication and initializing the API

# %% [markdown]
# Save your client ID and your client secret in your preferred way, and read it or load it into the following variables:

# %%
CLIENT_ID = "<introduce your client id>"
CLIENT_SECRET = "<introduce your client secret>"

# %%
CLIENT_ID = "4109b2d9f5014671863bb2df1d1fbdd3"
CLIENT_SECRET = "5cb719fae80c4191a9c0b288f51bfe50"

# %%
# If you havent done so, install the spotipy wrapper
# !pip install spotipy

# %% [markdown]
# Once you have done it, we will start initializing the API.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=CLIENT_ID,
                                                           client_secret=CLIENT_SECRET))

# %% [markdown]
# ## Using the search method

# %% [markdown]
# Now, let's use the search method by introducing a "query". For example, let's try searching for "Lady Gaga":

# %%
results = sp.search(q='Lady Gaga', limit=50)
results

# %%
results.keys() # We can see that we only have tracks
# Out:
# dict_keys(['tracks'])

# %%
results["tracks"].keys() # Let's check the values
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
results["tracks"]["href"] # Query we have searched
# Out:
# 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=0&limit=50'

# %%
results["tracks"]["items"] #items (actual tracks)
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VIvfOurcf0vuLRxLkGnIG'},
#      'href': 'https://api.spotify.com/v1/artists/4VIvfOurcf0vuLRxLkGnIG',
#      'id': '4VIvfOurcf0vuLRxLkGnIG',
#      'name': 'Bradley Cooper',
#      'type': 'artist',
#      'uri': 'spotify:artist:4VIvfOurcf0vuLRxLkGnIG'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
# ...

# %%
results["tracks"]["limit"]#Limit we have chosen
# Out:
# 50

# %%
results["tracks"]["next"] #link to the next page (next 50 tracks)
# Out:
# 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=50&limit=50'

# %%
results["tracks"]["offset"] # Actual offset (starting point)
# Out:
# 0

# %%
results["tracks"]["previous"] #Previous search

# %%
results["tracks"]["total"] # Number of matches
# Out:
# 955

# %% [markdown]
# ## Exploring the tracks

# %%
results["tracks"]["items"][0] # Explore the first song
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VIvfOurcf0vuLRxLkGnIG'},
#     'href': 'https://api.spotify.com/v1/artists/4VIvfOurcf0vuLRxLkGnIG',
#     'id': '4VIvfOurcf0vuLRxLkGnIG',
#     'name': 'Bradley Cooper',
#     'type': 'artist',
#     'uri': 'spotify:artist:4VIvfOurcf0vuLRxLkGnIG'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
# ...

# %%
results["tracks"]["items"][0].keys() # We will focus on album, artists, id, name, popularity, type and uri
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
# Track artists
results["tracks"]["items"][0]["artists"]
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#   'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#   'id': '1HY2Jd0NmPuamShAr6KMms',
#   'name': 'Lady Gaga',
#   'type': 'artist',
#   'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}]

# %%
# Track artists names
for artist in results["tracks"]["items"][0]["artists"]:
    print(artist["name"])
# Out:
# Lady Gaga

# %%
# Track ID
results["tracks"]["items"][0]["id"]
# Out:
# '2rbDhOo9Fh61Bbu23T2qCk'

# %%
# Track name
results["tracks"]["items"][0]["name"]
# Out:
# 'Always Remember Us This Way'

# %%
# Popularity index
results["tracks"]["items"][0]["popularity"]
# Out:
# 83

# %% [markdown]
# Spotify songs are identified by either a "url", a "uri", or an "id".
#
# - The `id` is an alphanumeric code, and it's the nuclear part of the identifier.
#
# - The `uri` contains "spotify:track" before the id. An uri is useful because it can be searched manually in the Spotify app.
#
# - The `url` is a link to the song on the Spotify web player.

# %%
results["tracks"]["items"][0]["uri"]
# Out:
# 'spotify:track:2rbDhOo9Fh61Bbu23T2qCk'

# %% [markdown]
# ## Exercise 1: Discovering New Music through Your Favorite Artists
#
# **Objective:**
# Uncover new music by exploring the top tracks of your favorite artists and their related artists.
#
# **Instructions:**
#
# 1. **List Your Favorite Artists**:
#     - Make a list of your three favorite artists and store it in a variable named `artists`.
#     - Example: `artists = ["Los Fabulosos Cadillacs", "Manu Chao", "Muchachito Bombo Infierno"]`.
#
# 2. **Fetch Top Tracks**:
#     - Write a function named `get_top_tracks`.
#     - This function should accept an artist's name and return the name of the first 5 top tracks by that artist.
#     - Use the function `get_top_tracks` to get the first 5 top tracks for each artist in your `artists` list and store the results in a new list named `top_tracks_list`.
#
# 3. **Discover Related Artists**:
#     - Write a function named `find_related_artists`.
#     - This function should accept an artist's name and return the names of the first 5 artists related to the provided artist.
#     - Store the results in a list named `related_artists_list`.
#
# **Challenge:**
# Combine the above steps to create a playlist that includes the top tracks of your favorite artists and the top tracks of the artists related to them.

# %% [markdown]
# **Hint Section for 3. **Discover Related Artists**:**
#
# 1. **Getting Artist ID**:
#     - Remember that every artist on Spotify has a unique identifier: their `id`. To get the related artists, you first need to fetch the ID of the given artist.
#     - Consider using the `sp.search` method to query the artist's name. The method requires a `q` parameter, which is your query (in this case, the artist's name). It also has a `limit` parameter, which specifies the number of tracks it returns. In this case, 1 track is enough, since we just want the artist ID.
#     - Each track in the results has an associated 'artists' field. This field is a list containing details about all artists involved in that track.
#    - For most tracks, especially those by a single artist, this list will contain one artist. From this artist's details, you can extract the 'id' field, which is the unique identifier for that artist on Spotify.
#
#
# 3. **Fetching Related Artists**:
#     - Once you have the artist's ID, you can use another SpotiPy method to fetch related artists. Think about which SpotiPy method allows you to get related artists using an artist's ID. Here is the documentation link: https://spotipy.readthedocs.io/en/2.22.1/.
#     - This method will return a list of related artists. You'll need to extract the relevant details (artist names) from this list.
#
# 4. **Iterating for Multiple Artists**:
#     - Once you have a function that returns related artists names for one artist, you can use a list comprehension to apply this function to a list of artist names.
#
# 5. **Testing**:
#     - Always test your function with one artist name first. Once you're confident it works, then apply it to the entire list.
#
# Remember, the key is to break the problem down into manageable steps. Use the SpotiPy documentation as a resource to understand available methods and their return structures.

# %%
#1 Make a list of your three favorite artists and store it in a variable named artists.

artists = ["U2", "Alejandro Sanz", "Luis Miguel"]

# %%
#2. Write a function named get_top_tracks.
#This function should accept an artist's name and return the name of the first 5 top tracks by that artist.
#Use the function get_top_tracks to get the first 5 top tracks for each artist in your artists list and store 
#the results in a new list named top_tracks_list.

import pandas as pd

artists = ["U2", "Alejandro Sanz", "Luis Miguel"]

def get_top_tracks(artists):
    top_tracks_list = []  
    
    for artist in artists:
        
        r2 = sp.search(q=artist, type='artist', limit=1)  
        if r2['artists']['items']:
            artist_name = r2['artists']['items'][0]['name']  # getting the artist's name
            artist_id = r2['artists']['items'][0]['id']  # getting the artist's id
            
            # getting the top tracks
            top_tracks = sp.artist_top_tracks(artist_id)
            
          
            count = 0
            for track in top_tracks['tracks']:
                if count >= 5:  # just 5 tracks
                    break
                track_name = track['name']
                top_tracks_list.append({'artist': artist_name, 'track': track_name}) 
                count += 1
    
    return top_tracks_list

# call the function
top_tracks_list = get_top_tracks(artists)

# print the list
top_tracks_list
# Out:
# [{'artist': 'U2', 'track': 'With Or Without You'},
#  {'artist': 'U2', 'track': "I Still Haven't Found What I'm Looking For"},
#  {'artist': 'U2', 'track': 'Beautiful Day'},
#  {'artist': 'U2', 'track': 'One'},
#  {'artist': 'U2', 'track': 'Sunday Bloody Sunday - Remastered 2008'},
#  {'artist': 'Alejandro Sanz', 'track': 'La tortura'},
#  {'artist': 'Alejandro Sanz', 'track': 'Amiga mía'},
#  {'artist': 'Alejandro Sanz', 'track': 'Corazón partío'},
#  {'artist': 'Alejandro Sanz',
#   'track': 'El Ultimo Adiós - Varios Artistas Version'},
#  {'artist': 'Alejandro Sanz', 'track': 'Mi soledad y yo'},
#  {'artist': 'Luis Miguel', 'track': 'Ahora Te Puedes Marchar'},
#  {'artist': 'Luis Miguel', 'track': 'La Incondicional'},
#  {'artist': 'Luis Miguel', 'track': 'La Media Vuelta'},
#  {'artist': 'Luis Miguel', 'track': 'Hasta Que Me Olvides'},
#  {'artist': 'Luis Miguel', 'track': 'Culpable O No - Miénteme Como Siempre'}]

# %%
#into a dataframe
top_tracks_list_df=pd.DataFrame(top_tracks_list)
top_tracks_list_df
# Out:
#             artist                                       track
# 0               U2                         With Or Without You
# 1               U2  I Still Haven't Found What I'm Looking For
# 2               U2                               Beautiful Day
# 3               U2                                         One
# 4               U2      Sunday Bloody Sunday - Remastered 2008
# 5   Alejandro Sanz                                  La tortura
# 6   Alejandro Sanz                                   Amiga mía
# 7   Alejandro Sanz                              Corazón partío
# 8   Alejandro Sanz   El Ultimo Adiós - Varios Artistas Version
# 9   Alejandro Sanz                             Mi soledad y yo
# 10     Luis Miguel                     Ahora Te Puedes Marchar
# 11     Luis Miguel                            La Incondicional
# 12     Luis Miguel                             La Media Vuelta
# 13     Luis Miguel                        Hasta Que Me Olvides
# ...

# %%
#3. Write a function named find_related_artists.
#This function should accept an artist's name and return the names of the first 5 artists related to the provided artist.
#Store the results in a list named related_artists_list.
#Once you have a function that returns related artists names for one artist, you can use a list comprehension to apply 
#this function to a list of artist names.

def find_related_artists(artist_name):
    
    search_result = sp.search(q=artist_name, type='artist', limit=1)
    
    if search_result['artists']['items']:
        artist_id = search_result['artists']['items'][0]['id']  # getting id
        
        # getting related artist
        related_artists = sp.artist_related_artists(artist_id)
        
        # getting the 5 related artist
        related_artists_list = [artist['name'] for artist in related_artists['artists'][:5]]
        return related_artists_list
    else:
        print(f"Artist {artist_name} not found!")
        return []



# List of artists to find related artists for
artists = ["U2", "Alejandro Sanz", "Luis Miguel"]

# Applying the function to a list of artist names using list comprehension
related_artists_all = {artist: find_related_artists(artist) for artist in artists}
print(related_artists_all)
# Out:
# {'U2': ['R.E.M.', 'INXS', 'The Police', 'Simple Minds', 'Lenny Kravitz'], 'Alejandro Sanz': ['David Bisbal', 'Alex Ubago', 'Miguel Bosé', 'Franco De Vita', 'La Quinta Estacion'], 'Luis Miguel': ['Alejandro Fernández', 'Cristian Castro', 'José José', 'Emmanuel', 'Mijares']}

# %%
#into a dataframe
related_artists_all_df=pd.DataFrame(related_artists_all)
related_artists_all_df
# Out:
#               U2      Alejandro Sanz          Luis Miguel
# 0         R.E.M.        David Bisbal  Alejandro Fernández
# 1           INXS          Alex Ubago      Cristian Castro
# 2     The Police         Miguel Bosé            José José
# 3   Simple Minds      Franco De Vita             Emmanuel
# 4  Lenny Kravitz  La Quinta Estacion              Mijares

# %%
#Challenge: Combine the above steps to create a playlist that includes the top tracks of your favorite artists 
#and the top tracks of the artists related to them.

def get_related_artists_top_tracks(artists):
    all_track_ids = [] 

    for artist in artists:
        # getting top tracks
        print(f"Fetching top tracks for {artist}...")
        top_tracks = get_artist_top_tracks(artist)
        all_track_ids.extend(top_tracks)  
        
        # get related artists
        related_artists = find_related_artists(artist)
        print(f"Related artists to {artist}: {related_artists}")
        
        #getting top tracks related artirts
        for related_artist in related_artists:
            print(f"Fetching top tracks for related artist {related_artist}...")
            top_related_tracks = get_artist_top_tracks(related_artist)
            all_track_ids.extend(top_related_tracks)  

    return all_track_ids
    
def create_playlist(user_id, playlist_name):
    # create playlist
    playlist = sp.user_playlist_create(user_id, name=playlist_name, public=True, description="Top tracks of favorite and related artists")
    return playlist['id']  # Retourner l'ID de la playlist

def add_tracks_to_playlist(user_id, playlist_id, track_ids):
    # adding tracks to the playlist
    sp.user_playlist_add_tracks(user_id, playlist_id, track_ids)
    print(f"Added {len(track_ids)} tracks to playlist {playlist_id}.")

# %%
user_id = sp.me()['id']


artists = ["U2", "Alejandro Sanz", "Luis Miguel"]

top_tracks_all = get_related_artists_top_tracks(artists)

playlist_id = create_playlist(user_id, "Favorite Artists and Related Top Tracks")

add_tracks_to_playlist(user_id, playlist_id, top_tracks_all)

# %% [markdown]
# ## Playlists
#
# The `sp.featured_playlists()` method in `spotipy` fetches a list of Spotify's featured playlists at a given moment. These are curated playlists that Spotify often highlights on the platform's homepage. The method provides a snapshot of the playlists that are being promoted or featured by Spotify at the time of the request.
#
# Once you've fetched the featured playlists, you can extract their IDs (and other details).

# %%
sp.featured_playlists() # We get a playlist id of a playlist we like

# %% [markdown]
# ### Getting a Playlist's Details
# To fetch details about a specific playlist, you can use the playlist method. You'll need the playlist's Spotify ID.

# %% [markdown]
# In this example, we will use the following playlist id: *37i9dQZF1DXd9zR7tdziuQ*

# %%
playlist_id = "37i9dQZF1DWVuV87wUBNwc"
playlist = sp.playlist(playlist_id)

# %%
print(playlist['name'])  # Print the playlist's name
print(playlist['description'])  # Print the playlist's description
# Out:
# Hits du Moment
# Lady Gaga, Bruno Mars au sommet de la première playlist de France.

# %% [markdown]
# ### Getting Tracks from a Playlist
# If you want to get the tracks from a specific playlist, you can use the playlist_tracks method.

# %%
tracks = sp.playlist_tracks(playlist_id)
for track in tracks['items']:
    print(track['track']['name'])  # Print each track's name
# Out:
# Die With A Smile
# SOIS PAS TIMIDE
# Si Antes Te Hubiera Conocido
# Alibi (with Pabllo Vittar & Yseult)
# Passe ton chemin
# Gata Only
# Nightcall
# Stargazing
# Wayeh
# Move
# Rosa
# Austin (Boots Stop Workin')
# It's Not Right But It's Okay
# SPIDER
# The Door
# Plus L'Time (Stereo Love)
# A Bar Song (Tipsy)
# Imagine
# Dancing In The Flames
# Beautiful Things
# Boucan (feat. Franglish)
# The Sound of Silence - CYRIL Remix
# feelslikeimfallinginlove
# Chaque seconde (feat. M. Pokora)
# Espresso
# Terminal 2F
# Queen of My Castle
# Belong Together
# Si seulement...
# I Don't Wanna Wait
# Monaco
# Yamore - Edit Version
# Good Luck, Babe!
# Recommence-moi
# Heaven
# Mélanine
# Wake Up
# Ton regard
# feelings don't lie
# Bene
# BIRDS OF A FEATHER
# Nous on sait
# Cry Baby
# WE PRAY
# Adieu
# The Emptiness Machine
# Danza Kuduro - Tiësto Remix
# Taste
# Summer Body
# Carry You Home

# %% [markdown]
# ### Getting Artists from a Playlist
#
# To extract all the artists from the tracks in a playlist, you'd typically follow these steps:
#
# 1. Fetch the playlist's tracks.
# 2. Iterate through each track.
# 3. For each track, extract the associated artists.

# %%
# List to store unique artist names
artists_list = []

for track_item in tracks['items']:
    track = track_item['track']
    for artist in track['artists']:
        artist_name = artist['name']
        if artist_name not in artists_list:  # This ensures each artist is added only once
            artists_list.append(artist_name)

print(artists_list)
# Out:
# ['Lady Gaga', 'Bruno Mars', 'GIMS', 'KAROL G', 'Sevdaliza', 'Pabllo Vittar', 'Yseult', 'Lynda', 'FloyyMenor', 'Cris Mj', 'Kavinsky', 'Angèle', 'Phoenix', 'Myles Smith', 'THEODORT', 'Adam Port', 'Stryv', 'Keinemusik', 'Orso', 'Malachiii', 'RIDSA', 'Dasha', 'Mr. Belt & Wezol', 'DYSTINCT', 'Teddy Swims', 'Léa Zelia', 'Edward Maya', 'Adryano', 'Shaboozey', 'Carbonne', 'The Weeknd', 'Benson Boone', 'KeBlack', 'Franglish', 'Disturbed', 'CYRIL', 'Coldplay', 'Pierre Garnier', 'M. Pokora', 'Sabrina Carpenter', 'Dadju', 'Kris Kross Amsterdam', 'INNA', 'Mark Ambor', 'Kendji Girac', 'David Guetta', 'OneRepublic', 'Guy2Bezbar', 'MoBlack', 'Salif Keita', 'Benja (NL)', 'Franc Fala', 'Cesária Evora', 'Chappell Roan', 'SANTA', 'Sound Of Legend', "Heuss L'enfoiré", 'Werenoi', 'Imagine Dragons', 'Joseph Kamel', 'Ofenbach', 'salem ilese', 'Billie Eilish', 'Clean Bandit', 'Anne-Marie', 'Little Simz', 'Burna Boy', 'Elyanna', 'TINI', 'Jérémy Frerot', 'Linkin Park', 'Don Omar', 'Lucenzo', 'Tiësto', 'Helena'
# ...

# %% [markdown]
# ## Exercise 2: Unraveling the World of Playlists
#
#
# 1. **Featured Exploration**:
#    - Fetch the list of Spotify's current featured playlists.
#    - Extract and display the names and IDs of the top 5 featured playlists.
#
# 2. **Deep Dive**:
#    - Choose any one of the top 5 featured playlists (you can choose the one you personally find most interesting or simply pick one randomly).
#    - Fetch and display its name, description, and total track count.
#
# 3. **Track-tastic**:
#    - Extract and display the names of the first 10 tracks in the chosen playlist.
#
# 4. **Artistic Flair**:
#    - Create a dictionary where the keys are the names of the first 10 tracks, and the values are lists containing the names of the artists associated with each track.
#    - For example: `{"TrackName1": ["Artist1", "Artist2"], "TrackName2": ["Artist3"]}`

# %%
# 1: Featured Exploration:
#Fetch the list of Spotify's current featured playlists.
#Extract and display the names and IDs of the top 5 featured playlists.

def get_featured_playlists():
    featured_playlists = sp.featured_playlists(limit=5)  # Get top 5 featured playlists
    playlist_data = []
    
    for playlist in featured_playlists['playlists']['items']:
        playlist_name = playlist['name']
        playlist_id = playlist['id']
        playlist_data.append({'name': playlist_name, 'id': playlist_id})
    
    return playlist_data

# %%
#2. Deep Dive:
#Choose any one of the top 5 featured playlists (you can choose the one you personally find most interesting or simply pick one randomly).
#Fetch and display its name, description, and total track count.
def get_playlist_details(playlist_id):
    playlist_info = sp.playlist(playlist_id)
    name = playlist_info['name']
    description = playlist_info['description']
    total_tracks = playlist_info['tracks']['total']
    
    return {
        'name': name,
        'description': description,
        'total_tracks': total_tracks
    }

# %%
# 3: Track-tastic: Extract and display the names of the first 10 tracks in the chosen playlist.
def get_first_10_tracks(playlist_id):
    tracks_info = sp.playlist_tracks(playlist_id, limit=10)
    track_names = [track['track']['name'] for track in tracks_info['items']]
    return track_names

# %%
#4. Artistic Flair: Create a dictionary where the keys are the names of the first 10 tracks, 
#and the values are lists containing the names of the artists associated with each track.
#For example: {"TrackName1": ["Artist1", "Artist2"], "TrackName2": ["Artist3"]}

def get_track_artist_dict(playlist_id):
    tracks_info = sp.playlist_tracks(playlist_id, limit=10)
    
    track_artist_dict = {}
    
    for track in tracks_info['items']:
        track_name = track['track']['name']
        artists = [artist['name'] for artist in track['track']['artists']]
        track_artist_dict[track_name] = artists
    
    return track_artist_dict

# %%
# Fetch top 5 featured playlists
featured_playlists = get_featured_playlists()
print("Top 5 Featured Playlists:")
for playlist in featured_playlists:
    print(f"Playlist Name: {playlist['name']}, Playlist ID: {playlist['id']}")

# Choose one of the top 5 playlists 
chosen_playlist_id = featured_playlists[3]['id']

# Get details of the chosen playlist
playlist_details = get_playlist_details(chosen_playlist_id)
print(f"\nChosen Playlist Details:\nName: {playlist_details['name']}\nDescription: {playlist_details['description']}\nTotal Tracks: {playlist_details['total_tracks']}")

# Get first 10 tracks of the chosen playlist
first_10_tracks = get_first_10_tracks(chosen_playlist_id)
print("\nFirst 10 Tracks:")
print(first_10_tracks)

# Get dictionary of track names and their associated artists
track_artist_dict = get_track_artist_dict(chosen_playlist_id)
print("\nTrack and Artists Dictionary:")
print(track_artist_dict)
# Out:
# Top 5 Featured Playlists:
# Playlist Name: Hits du Moment, Playlist ID: 37i9dQZF1DWVuV87wUBNwc
# Playlist Name: t'as la ref ?, Playlist ID: 37i9dQZF1DXdvyLcddcaVU
# Playlist Name: PVNCHLNRS, Playlist ID: 37i9dQZF1DX1X23oiQRTB5
# Playlist Name: Best Life, Playlist ID: 37i9dQZF1DWYVURwQHUqnN
# Playlist Name: New Music Friday France, Playlist ID: 37i9dQZF1DX742okrrpwah
#
# Chosen Playlist Details:
# Name: Best Life
# Description: Photo : GIMS
# Total Tracks: 40
#
# First 10 Tracks:
# ['SOIS PAS TIMIDE', 'Monaco', 'Coco', 'Bande organisée 2', 'TI TI TI', 'SPIDER', 'Une histoire', 'No lo sé', 'Enchanté', 'Vanillée']
#
# Track and Artists Dictionary:
# ...
